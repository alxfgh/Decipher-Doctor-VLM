# %%
import os
import random
import json
from PIL import Image
import numpy as np

def load_line_info(file_path, base_dir):
    line_info = {}
    with open(file_path, 'r') as f:
        for line in f:
            if line.startswith('#') or line.strip() == '':
                continue
            parts = line.strip().split()
            line_id = parts[0]
            transcription = ' '.join(parts[8:]).replace('|', ' ')
            
            # Construct the image path more flexibly
            form_id = line_id[:3]
            line_group = line_id[:8]
            image_filename = f"{line_id}.png"
            
            # Check for both possible directory structures
            possible_paths = [
                os.path.join(base_dir, "lines", form_id, line_group, image_filename),
                os.path.join(base_dir, "lines", form_id, f"{line_group}-", image_filename)
            ]
            
            image_path = next((path for path in possible_paths if os.path.exists(path)), None)
            
            if image_path:
                line_info[line_id] = {
                    'transcription': transcription,
                    'bounding_box': list(map(int, parts[4:8])),
                    'image_path': image_path
                }
            else:
                print(f"Warning: Image not found for line ID {line_id}")
    
    return line_info

def create_paragraph_image(line_info, num_lines):
    selected_lines = random.sample(list(line_info.keys()), num_lines)
    images = []
    transcriptions = []
    max_width = 0
    total_height = 0
    
    for line_id in selected_lines:
        img_path = line_info[line_id]['image_path']
        try:
            img = Image.open(img_path)
            images.append(img)
            transcriptions.append(line_info[line_id]['transcription'])
            max_width = max(max_width, img.width)
            total_height += img.height
        except Exception as e:
            print(f"Error opening image {img_path}: {e}")
            continue

    if not images:
        raise ValueError("No valid images found to create paragraph")

    # Add some padding
    max_width += 20
    total_height += 20 * (len(images) + 1)

    paragraph_image = Image.new('L', (max_width, total_height), color=255)
    y_offset = 10
    
    for img in images:
        x_offset = random.randint(0, 20)
        paragraph_image.paste(img, (x_offset, y_offset))
        y_offset += img.height + random.randint(5, 15)

    return paragraph_image, '\n'.join(transcriptions)

def generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples):
    line_info = load_line_info(line_info_path, base_dir)
    os.makedirs(output_path, exist_ok=True)
    dataset = []

    for i in range(num_samples):
        num_lines = random.randint(1, 5)
        try:
            image, transcription = create_paragraph_image(line_info, num_lines)
            
            image_filename = f"synthetic_paragraph_{i+1}.png"
            image_path = os.path.join(output_path, image_filename)
            image.save(image_path)
            
            data_entry = {
                "query": "what does this say?",
                "response": transcription,
                "images": [image_path]
            }
            dataset.append(data_entry)
        except Exception as e:
            print(f"Error generating paragraph {i+1}: {e}")
            continue

    return dataset

# Main execution
if __name__ == "__main__":
    base_dir = "C:\\Users\\alexg\\Coding Projects\\Medical-Handwriting-Training-Generator"
    line_info_path = os.path.join(base_dir, "lines.txt")
    output_path = os.path.join(base_dir, "synthetic_paragraphs")
    num_samples = 10000  # Adjust as needed

    dataset = generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples)

    # Save dataset to JSON file
    json_path = os.path.join(base_dir, 'synthetic_paragraph_dataset.json')
    with open(json_path, 'w') as f:
        json.dump(dataset, f, indent=4)

    print(f"{len(dataset)} synthetic paragraph images have been generated and saved in {output_path}.")
    print(f"Dataset information has been saved to {json_path}.")
# Out:
# Warning: Image not found for line ID a01-003-00
# Warning: Image not found for line ID a01-003-01
# Warning: Image not found for line ID a01-003-02
# Warning: Image not found for line ID a01-003-03
# Warning: Image not found for line ID a01-003-04
# Warning: Image not found for line ID a01-003-05
# Warning: Image not found for line ID r06-126-08
# Warning: Image not found for line ID r06-126-09
# Warning: Image not found for line ID r06-126-10
# Warning: Image not found for line ID r06-130-00
# Warning: Image not found for line ID r06-130-01
# Warning: Image not found for line ID r06-130-02
# Warning: Image not found for line ID r06-130-03
# Warning: Image not found for line ID r06-130-04
# Warning: Image not found for line ID r06-130-05
# Warning: Image not found for line ID r06-130-06
# Warning: Image not found for line ID r06-130-07
# Warning: Image not found for line ID r06-130-08
# Warning: Image not found for line ID r06-130-09
# Warning: Image not found for line ID r06-137-00
# Warning: Image not found for line ID r06-137-01
# Warning: Image not found for line ID r06-137-02
# Warning: Image not found for line ID r06-137-03
# Warning: Image not found for line ID r06-137-04
# Warning: Image not found for line ID r06-137-05
# Warning: Image not found for line ID r06-137-06
# Warning: Image not found for line ID r06-137-07
# Warning: Image not found for line ID r06-137-08
# Warning: Image not found for line ID r06-137-09
# Warning: Image not found for line ID r06-137-10
# Warning: Image not found for line ID r06-143-00
# Warning: Image not found for line ID r06-143-01
# Warning: Image not found for line ID r06-143-02
# Warning: Image not found for line ID r06-143-03
# Warning: Image not found for line ID r06-143-04
# 100 synthetic paragraph images have been generated and saved in C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs.
# Dataset information has been saved to C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraph_dataset.json.

# %%
import os
import random
import json
from PIL import Image
import numpy as np

def load_line_info(file_path, base_dir):
    line_info = {}
    for line in open(file_path, 'r'):
        if line.startswith('#') or line.strip() == '':
            continue
        parts = line.strip().split()
        line_id = parts[0]
        transcription = ' '.join(parts[8:]).replace('|', ' ')
        
        form_id = line_id[:3]
        line_group = line_id[:8]
        image_filename = f"{line_id}.png"
        
        possible_paths = [
            os.path.join(base_dir, "lines", form_id, line_group, image_filename),
            os.path.join(base_dir, "lines", form_id, f"{line_group}-", image_filename)
        ]
        
        image_path = next((path for path in possible_paths if os.path.exists(path)), None)
        
        if image_path:
            try:
                # Attempt to open the image to ensure it's valid
                with Image.open(image_path) as img:
                    line_info[line_id] = {
                        'transcription': transcription,
                        'bounding_box': list(map(int, parts[4:8])),
                        'image_path': image_path
                    }
            except Exception:
                # If the image can't be opened, we simply don't add it to line_info
                pass
    
    return line_info

def create_paragraph_image(line_info, num_lines):
    selected_lines = random.sample(list(line_info.keys()), num_lines)
    images = []
    transcriptions = []
    
    for line_id in selected_lines:
        img_path = line_info[line_id]['image_path']
        img = Image.open(img_path)
        images.append(img)
        transcriptions.append(line_info[line_id]['transcription'])

    max_width = max(img.width for img in images) + 20
    total_height = sum(img.height for img in images) + 20 * (len(images) + 1)

    paragraph_image = Image.new('L', (max_width, total_height), color=255)
    y_offset = 10
    
    for img in images:
        x_offset = random.randint(0, 20)
        paragraph_image.paste(img, (x_offset, y_offset))
        y_offset += img.height + random.randint(5, 15)

    return paragraph_image, '\n'.join(transcriptions)

def generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples):
    line_info = load_line_info(line_info_path, base_dir)
    os.makedirs(output_path, exist_ok=True)
    dataset = []

    print(f"Loaded {len(line_info)} valid line entries.")

    for i in range(num_samples):
        num_lines = random.randint(1, 5)
        image, transcription = create_paragraph_image(line_info, num_lines)
        
        image_filename = f"synthetic_paragraph_{i+1}.png"
        image_path = os.path.join(output_path, image_filename)
        image.save(image_path)
        
        data_entry = {
            "query": "what does this say?",
            "response": transcription,
            "images": [image_path]
        }
        dataset.append(data_entry)

    return dataset

# Main execution
if __name__ == "__main__":
    base_dir = "C:\\Users\\alexg\\Coding Projects\\Medical-Handwriting-Training-Generator"
    line_info_path = os.path.join(base_dir, "lines.txt")
    output_path = os.path.join(base_dir, "synthetic_paragraphs")
    num_samples = 1000  # Adjust as needed

    dataset = generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples)

    print(f"\nGenerated {len(dataset)} synthetic paragraph images.")

    # Save dataset to JSON file
    json_path = os.path.join(base_dir, 'synthetic_paragraph_dataset.json')
    with open(json_path, 'w') as f:
        json.dump(dataset, f, indent=4)

    print(f"\nDataset information has been saved to {json_path}.")
# Out:
# Loaded 2844 valid line entries.
#
# Generated 1000 synthetic paragraph images.
#
# Dataset information has been saved to C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraph_dataset.json.

# %%
# BIG FIX
import os
import random
import json
from PIL import Image

def load_line_info(file_path, base_dir):
    line_info = {}
    for line in open(file_path, 'r'):
        if line.startswith('#') or line.strip() == '':
            continue
        parts = line.strip().split()
        line_id = parts[0]
        transcription = ' '.join(parts[8:]).replace('|', ' ')
        
        form_id = line_id[:3]
        line_group = line_id[:8]
        image_filename = f"{line_id}.png"
        
        possible_paths = [
            os.path.join(base_dir, "lines", form_id, line_group, image_filename),
            os.path.join(base_dir, "lines", form_id, f"{line_group}-", image_filename)
        ]
        
        image_path = next((path for path in possible_paths if os.path.exists(path)), None)
        
        if image_path:
            try:
                with Image.open(image_path) as img:
                    line_info[line_id] = {
                        'transcription': transcription,
                        'bounding_box': list(map(int, parts[4:8])),
                        'image_path': image_path
                    }
            except Exception:
                pass
    
    return line_info

def process_paragraph_image(img, canvas_size=(512, 512), target_size=350):
    if img.width > img.height:
        scale_factor = target_size / img.width
    else:
        scale_factor = target_size / img.height
    
    new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
    
    img = img.resize(new_size, Image.Resampling.LANCZOS)
    
    rotation_angle = random.uniform(-20, 20)
    img = img.rotate(rotation_angle, expand=True, fillcolor=255)
    
    canvas = Image.new('L', canvas_size, color=255)
    
    max_x_offset = canvas_size[0] - img.width
    max_y_offset = canvas_size[1] - img.height
    x_offset = random.randint(0, max_x_offset)
    y_offset = random.randint(0, max_y_offset)
    
    canvas.paste(img, (x_offset, y_offset), img if img.mode == 'RGBA' else None)
    
    return canvas

def create_paragraph_image(line_info, num_lines):
    selected_lines = random.sample(list(line_info.keys()), num_lines)
    images = []
    transcriptions = []
    
    for line_id in selected_lines:
        img_path = line_info[line_id]['image_path']
        img = Image.open(img_path)
        images.append(img)
        transcriptions.append(line_info[line_id]['transcription'])

    max_width = max(img.width for img in images) + 20
    total_height = sum(img.height for img in images) + 20 * (len(images) + 1)

    paragraph_image = Image.new('L', (max_width, total_height), color=255)
    y_offset = 10
    
    for img in images:
        x_offset = random.randint(0, 20)
        paragraph_image.paste(img, (x_offset, y_offset))
        y_offset += img.height + random.randint(5, 15)

    return paragraph_image, '\n'.join(transcriptions)

def generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples, transformations_per_image=5):
    line_info = load_line_info(line_info_path, base_dir)
    os.makedirs(output_path, exist_ok=True)
    dataset = []

    print(f"Loaded {len(line_info)} valid line entries.")

    for i in range(num_samples):
        num_lines = random.randint(1, 5)
        original_image, transcription = create_paragraph_image(line_info, num_lines)
        
        for j in range(transformations_per_image):
            image_filename = f"good_paragraph_{i+1}_{j+1}.png"
            image_path = os.path.join(output_path, image_filename)
            
            # Process the original image with augmentation
            processed_image = process_paragraph_image(original_image)
            processed_image.save(image_path)
            
            # Store relative path and ensure consistent format
            image_paths = [f"synthetic_paragraphs/{image_filename}"]
            
            # Create a new data entry for each augmented image
            data_entry = {
                "query": "what does this say?",
                "response": transcription,
                "images": image_paths
            }
            dataset.append(data_entry)

    return dataset

# Main execution
if __name__ == "__main__":
    base_dir = os.getcwd()
    line_info_path = os.path.join(base_dir, "lines.txt")
    output_path = os.path.join(base_dir, "synthetic_paragraphs")
    num_samples = 1000  # Adjust as needed

    dataset = generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples)

    print(f"\nGenerated {len(dataset)} synthetic paragraph images with augmentations.")

    # Save dataset to JSON file
    json_path = os.path.join(base_dir, 'synthetic_notes_dataset.json')
    with open(json_path, 'w') as f:
        json.dump(dataset, f, indent=4)

    print(f"\nDataset information has been saved to {json_path}.")
# Out:
# Loaded 2844 valid line entries.
#
# Generated 5000 synthetic paragraph images with augmentations.
#
# Dataset information has been saved to c:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_notes_dataset.json.

# %%
import json
import random

# Load the dataset.json
with open('dataset.json', 'r') as f:
    dataset = json.load(f)

# Load the synthetic_notes_dataset.json
with open('synthetic_notes_dataset.json', 'r') as f:
    synthetic_notes_data = json.load(f)

# Combine the two datasets
combined_dataset = dataset + synthetic_notes_data

# Shuffle the combined dataset to ensure randomness
random.shuffle(combined_dataset)

# Split the combined dataset into 90% train and 10% validation
split_index = int(0.9 * len(combined_dataset))
train_data = combined_dataset[:split_index]
val_data = combined_dataset[split_index:]

# Save the train.json
with open('train.json', 'w') as f:
    json.dump(train_data, f, indent=4)

# Save the val.json
with open('val.json', 'w') as f:
    json.dump(val_data, f, indent=4)

print(f"Train and validation sets created: {len(train_data)} train samples, {len(val_data)} validation samples.")
# Out:
# Train and validation sets created: 11239 train samples, 1249 validation samples.

# %%
# mid way try
def process_paragraph_image(img, canvas_size=(512, 512), target_size=350):
    # Determine the scaling factor so that the largest dimension is 350px
    if img.width > img.height:
        scale_factor = target_size / img.width
    else:
        scale_factor = target_size / img.height
    
    # Calculate the new size
    new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
    
    # Resize the image while maintaining aspect ratio
    img = img.resize(new_size, Image.Resampling.LANCZOS)
    
    # Apply random rotation between -20 and +20 degrees
    rotation_angle = random.uniform(-20, 20)
    img = img.rotate(rotation_angle, expand=True, fillcolor=255)
    
    # Create a blank canvas of 512x512 with white background
    canvas = Image.new('L', canvas_size, color=255)
    
    # Generate random position for the image on the canvas
    max_x_offset = canvas_size[0] - img.width
    max_y_offset = canvas_size[1] - img.height
    x_offset = random.randint(0, max_x_offset)
    y_offset = random.randint(0, max_y_offset)
    
    # Paste the image onto the canvas
    canvas.paste(img, (x_offset, y_offset), img if img.mode == 'RGBA' else None)
    
    return canvas

def generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples, transformations_per_image=5):
    line_info = load_line_info(line_info_path, base_dir)
    os.makedirs(output_path, exist_ok=True)
    dataset = []

    print(f"Loaded {len(line_info)} valid line entries.")

    for i in range(num_samples):
        num_lines = random.randint(1, 5)
        original_image, transcription = create_paragraph_image(line_info, num_lines)
        
        image_paths = []
        for j in range(transformations_per_image):
            image_filename = f"good_paragraph_{i+1}_{j+1}.png"
            image_path = os.path.join(output_path, image_filename)
            
            # Process the original image
            processed_image = process_paragraph_image(original_image)
            processed_image.save(image_path)
            
            # Store only the relative path for Linux compatibility
            image_paths.append(f"good_paragraphs/{image_filename}")
        
        data_entry = {
            "query": "what does this say?",
            "response": transcription,
            "images": image_paths
        }
        dataset.append(data_entry)

    return dataset

# Main execution
if __name__ == "__main__":
    # Use current working directory instead of hardcoded path
    base_dir = os.getcwd()
    line_info_path = os.path.join(base_dir, "lines.txt")
    output_path = os.path.join(base_dir, "good_paragraphs")
    num_samples = 1000  # Adjust as needed

    dataset = generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples)

    print(f"\nGenerated {len(dataset)} synthetic paragraph images, each with 5 transformations.")

    # Save dataset to JSON file
    json_path = os.path.join(base_dir, 'synthetic_notes_dataset.json')
    with open(json_path, 'w') as f:
        json.dump(dataset, f, indent=4)

    print(f"\nDataset information has been saved to {json_path}.")
# Out:
# Loaded 2844 valid line entries.
#
# Generated 1000 synthetic paragraph images, each with 5 transformations.
#
# Dataset information has been saved to c:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_notes_dataset.json.

# %%
import os
import random
from PIL import Image

def process_paragraph_images(input_dir, output_dir, canvas_size=(512, 512), target_size=350):
    os.makedirs(output_dir, exist_ok=True)

    # Iterate through all images in the input directory
    for image_filename in os.listdir(input_dir):
        if image_filename.endswith('.png'):
            image_path = os.path.join(input_dir, image_filename)
            try:
                # Open image
                img = Image.open(image_path)
                
                # Determine the scaling factor so that the largest dimension is 350px
                if img.width > img.height:
                    scale_factor = target_size / img.width
                else:
                    scale_factor = target_size / img.height
                
                # Calculate the new size
                new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
                
                # Resize the image while maintaining aspect ratio
                img = img.resize(new_size, Image.Resampling.LANCZOS)
                
                # Apply random rotation between -20 and +20 degrees
                rotation_angle = random.uniform(-20, 20)
                img = img.rotate(rotation_angle, expand=True, fillcolor=255)
                
                # Create a blank canvas of 512x512 with white background
                canvas = Image.new('L', canvas_size, color=255)
                
                # Generate random position for the image on the canvas
                max_x_offset = canvas_size[0] - img.width
                max_y_offset = canvas_size[1] - img.height
                x_offset = random.randint(0, max_x_offset)
                y_offset = random.randint(0, max_y_offset)
                
                # Paste the image onto the canvas
                canvas.paste(img, (x_offset, y_offset), img if img.mode == 'RGBA' else None)
                
                # Save the processed image to the new folder
png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_386.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_387.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_388.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_389.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_39.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_390.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_391.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_392.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_393.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_394.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_395.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_396.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_397.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_398.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_399.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_4.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_40.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_400.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_401.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_402.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_403.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_404.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_405.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_406.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_407.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_408.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_409.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_41.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_410.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_411.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_412.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_413.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_414.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_415.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_416.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_417.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_418.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_419.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_42.png
# ...
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_892.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_893.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_894.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_895.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_896.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_897.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_898.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_899.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_9.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_90.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_900.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_901.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_902.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_903.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_904.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_905.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_906.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_907.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_908.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_909.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_91.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_910.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_911.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_912.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_913.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_914.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_915.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_916.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_917.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_918.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_919.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_92.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_920.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_921.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_922.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_923.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_924.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_925.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_926.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_927.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_928.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_929.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_93.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_930.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_931.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_932.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_933.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_934.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_935.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_936.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_937.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_938.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_939.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_94.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_940.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_941.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_942.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_943.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_944.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_945.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_946.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_947.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_948.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_949.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_95.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_950.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_951.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_952.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_953.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_954.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_955.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_956.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_957.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_958.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_959.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_96.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_960.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_961.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_962.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_963.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_964.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_965.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_966.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_967.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_968.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_969.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_97.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_970.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_971.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_972.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_973.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_974.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_975.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_976.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_977.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_978.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_979.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_98.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_980.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_981.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_982.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_983.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_984.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_985.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_986.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_987.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_988.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_989.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_99.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_990.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_991.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_992.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_993.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_994.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_995.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_996.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_997.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_998.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\paragraph_data\synthetic_paragraph_999.png

# %%
import os
import random
import json
from PIL import Image
import numpy as np

def load_line_info(file_path, base_dir):
    line_info = {}
    for line in open(file_path, 'r'):
        if line.startswith('#') or line.strip() == '':
            continue
        parts = line.strip().split()
        line_id = parts[0]
        transcription = ' '.join(parts[8:]).replace('|', ' ')
        
        form_id = line_id[:3]
        line_group = line_id[:8]
        image_filename = f"{line_id}.png"
        
        possible_paths = [
            os.path.join(base_dir, "lines", form_id, line_group, image_filename),
            os.path.join(base_dir, "lines", form_id, f"{line_group}-", image_filename)
        ]
        
        image_path = next((path for path in possible_paths if os.path.exists(path)), None)
        
        if image_path:
            try:
                # Attempt to open the image to ensure it's valid
                with Image.open(image_path) as img:
                    line_info[line_id] = {
                        'transcription': transcription,
                        'bounding_box': list(map(int, parts[4:8])),
                        'image_path': image_path
                    }
            except Exception:
                # If the image can't be opened, we simply don't add it to line_info
                pass
    
    return line_info

def create_paragraph_image(line_info, num_lines):
    selected_lines = random.sample(list(line_info.keys()), num_lines)
    images = []
    transcriptions = []
    
    for line_id in selected_lines:
        img_path = line_info[line_id]['image_path']
        img = Image.open(img_path)
        images.append(img)
        transcriptions.append(line_info[line_id]['transcription'])

    max_width = max(img.width for img in images) + 20
    total_height = sum(img.height for img in images) + 20 * (len(images) + 1)

    paragraph_image = Image.new('L', (max_width, total_height), color=255)
    y_offset = 10
    
    for img in images:
        x_offset = random.randint(0, 20)
        paragraph_image.paste(img, (x_offset, y_offset))
        y_offset += img.height + random.randint(5, 15)

    return paragraph_image, '\n'.join(transcriptions)

def generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples):
    line_info = load_line_info(line_info_path, base_dir)
    os.makedirs(output_path, exist_ok=True)
    dataset = []

    print(f"Loaded {len(line_info)} valid line entries.")

    for i in range(num_samples):
        num_lines = random.randint(1, 5)
        image, transcription = create_paragraph_image(line_info, num_lines)
        
        image_filename = f"synthetic_paragraph_{i+1}.png"
        image_path = os.path.join(output_path, image_filename)
        image.save(image_path)
        
        data_entry = {
            "query": "what does this say?",
            "response": transcription,
            "images": [image_path]
        }
        dataset.append(data_entry)

    return dataset

def process_paragraph_images(input_dir, output_dir, canvas_size=(512, 512), target_size=350):
    os.makedirs(output_dir, exist_ok=True)

    processed_dataset = []

    # Iterate through all images in the input directory
    for image_filename in os.listdir(input_dir):
        if image_filename.endswith('.png'):
            image_path = os.path.join(input_dir, image_filename)
            try:
                # Open image
                img = Image.open(image_path)
                
                # Determine the scaling factor so that the largest dimension is 350px
                if img.width > img.height:
                    scale_factor = target_size / img.width
                else:
                    scale_factor = target_size / img.height
                
                # Calculate the new size
                new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
                
                # Resize the image while maintaining aspect ratio
                img = img.resize(new_size, Image.Resampling.LANCZOS)
                
                # Apply random rotation between -20 and +20 degrees
                rotation_angle = random.uniform(-20, 20)
                img = img.rotate(rotation_angle, expand=True, fillcolor=255)
                
                # Create a blank canvas of 512x512 with white background
                canvas = Image.new('L', canvas_size, color=255)
                
                # Generate random position for the image on the canvas
                max_x_offset = canvas_size[0] - img.width
                max_y_offset = canvas_size[1] - img.height
                x_offset = random.randint(0, max_x_offset)
                y_offset = random.randint(0, max_y_offset)
                
                # Paste the image onto the canvas
                canvas.paste(img, (x_offset, y_offset), img if img.mode == 'RGBA' else None)
                
                # Save the processed image to the new folder
                output_image_path = os.path.join(output_dir, image_filename)
                canvas.save(output_image_path)
                
                print(f"Processed and saved: {output_image_path}")

                # Update the dataset with the new image path
                for entry in processed_dataset:
                    if entry['images'][0] == image_path:
                        entry['images'][0] = output_image_path
                        break

            except Exception as e:
                print(f"Failed to process {image_filename}: {e}")

    return processed_dataset

# Main execution
if __name__ == "__main__":
    base_dir = "C:\\Users\\alexg\\Coding Projects\\Medical-Handwriting-Training-Generator"
    line_info_path = os.path.join(base_dir, "lines.txt")
    good_paragraphs_path = os.path.join(base_dir, "good_paragraphs")
    synthetic_paragraphs_path = os.path.join(base_dir, "synthetic_paragraphs")
    num_samples = 1000  # Adjust as needed

    # Generate high-quality images
    dataset = generate_synthetic_dataset(line_info_path, base_dir, good_paragraphs_path, num_samples)

    print(f"\nGenerated {len(dataset)} high-quality paragraph images.")

    # Save dataset to JSON file
    json_path = os.path.join(base_dir, 'good_paragraphs_dataset.json')
    with open(json_path, 'w') as f:
        json.dump(dataset, f, indent=4)

    print(f"\nHigh-quality dataset information has been saved to {json_path}.")

    # Process the high-quality images
    processed_dataset = process_paragraph_images(good_paragraphs_path, synthetic_paragraphs_path)

    print(f"\nProcessed {len(processed_dataset)} paragraph images.")

    # Save processed dataset to JSON file
    processed_json_path = os.path.join(base_dir, 'synthetic_paragraph_dataset.json')
    with open(processed_json_path, 'w') as f:
        json.dump(processed_dataset, f, indent=4)

    print(f"\nProcessed dataset information has been saved to {processed_json_path}.")
# Out:
# Loaded 2844 valid line entries.
#
# Generated 1000 high-quality paragraph images.
#
# High-quality dataset information has been saved to C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\good_paragraphs_dataset.json.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 171
#     168 print(f"\nHigh-quality dataset information has been saved to {json_path}.")
#     170 # Process the high-quality images
# --> 171 processed_dataset = process_paragraph_images(good_paragraphs_path, synthetic_paragraphs_path)
#     173 print(f"\nProcessed {len(processed_dataset)} paragraph images.")
#     175 # Save processed dataset to JSON file
#
# TypeError: process_paragraph_images() missing 1 required positional argument: 'original_dataset'

# %%
import os
import random
import json
from PIL import Image
import numpy as np

def load_line_info(file_path, base_dir):
    line_info = {}
    for line in open(file_path, 'r'):
        if line.startswith('#') or line.strip() == '':
            continue
        parts = line.strip().split()
        line_id = parts[0]
        transcription = ' '.join(parts[8:]).replace('|', ' ')
        form_id = line_id[:3]
        line_group = line_id[:8]
        image_filename = f"{line_id}.png"
        possible_paths = [
            os.path.join(base_dir, "lines", form_id, line_group, image_filename),
            os.path.join(base_dir, "lines", form_id, f"{line_group}-", image_filename)
        ]
        image_path = next((path for path in possible_paths if os.path.exists(path)), None)
        if image_path:
            try:
                with Image.open(image_path) as img:
                    line_info[line_id] = {
                        'transcription': transcription,
                        'bounding_box': list(map(int, parts[4:8])),
                        'image_path': image_path
                    }
            except Exception:
                pass
    return line_info

def create_paragraph_image(line_info, num_lines):
    selected_lines = random.sample(list(line_info.keys()), num_lines)
    images = []
    transcriptions = []

    for line_id in selected_lines:
        img_path = line_info[line_id]['image_path']
        img = Image.open(img_path)
        images.append(img)
        transcriptions.append(line_info[line_id]['transcription'])

    max_width = max(img.width for img in images) + 20
    total_height = sum(img.height for img in images) + 20 * (len(images) + 1)

    paragraph_image = Image.new('L', (max_width, total_height), color=255)
    y_offset = 10

    for img in images:
        x_offset = random.randint(0, 20)
        paragraph_image.paste(img, (x_offset, y_offset))
        y_offset += img.height + random.randint(5, 15)

    return paragraph_image, '\n'.join(transcriptions)

def generate_synthetic_dataset(line_info_path, base_dir, output_path, num_samples):
    line_info = load_line_info(line_info_path, base_dir)
    os.makedirs(output_path, exist_ok=True)
    dataset = []

    print(f"Loaded {len(line_info)} valid line entries.")

    for i in range(num_samples):
        num_lines = random.randint(1, 5)
        image, transcription = create_paragraph_image(line_info, num_lines)

        image_filename = f"goodparagraph{i+1}.png"
        image_path = os.path.join(output_path, image_filename)
        image.save(image_path)

        data_entry = {
            "query": "what does this say?",
            "response": transcription,
            "images": [image_path]
        }
        dataset.append(data_entry)

    return dataset

def process_paragraph_images(input_dir, output_dir, canvas_size=(512, 512), target_size=350):
    os.makedirs(output_dir, exist_ok=True)

    for image_filename in os.listdir(input_dir):
        if image_filename.endswith('.png'):
            image_path = os.path.join(input_dir, image_filename)
            try:
                img = Image.open(image_path)

                if img.width > img.height:
                    scale_factor = target_size / img.width
                else:
                    scale_factor = target_size / img.height

                new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
                img = img.resize(new_size, Image.Resampling.LANCZOS)

                rotation_angle = random.uniform(-20, 20)
                img = img.rotate(rotation_angle, expand=True, fillcolor=255)

                canvas = Image.new('L', canvas_size, color=255)
                max_x_offset = canvas_size[0] - img.width
                max_y_offset = canvas_size[1] - img.height
                x_offset = random.randint(0, max_x_offset)
                y_offset = random.randint(0, max_y_offset)

                canvas.paste(img, (x_offset, y_offset))

                output_image_path = os.path.join(output_dir, image_filename)
                canvas.save(output_image_path)

                print(f"Processed and saved: {output_image_path}")
            except Exception as e:
                print(f"Failed to process {image_filename}: {e}")

# Main execution
if __name__ == "__main__":
    base_dir = "C:\\Users\\alexg\\Coding Projects\\Medical-Handwriting-Training-Generator"
    line_info_path = os.path.join(base_dir, "lines.txt")
    
    # First step: Generate high-quality images in 'good_paragraphs'
    good_paragraph_output = os.path.join(base_dir, "good_paragraphs")
    num_samples = 1000  # Adjust as needed
    good_dataset = generate_synthetic_dataset(line_info_path, base_dir, good_paragraph_output, num_samples)
    
    good_json_path = os.path.join(base_dir, 'good_paragraph_dataset.json')
    with open(good_json_path, 'w') as f:
        json.dump(good_dataset, f, indent=4)
    
    print(f"\nGenerated {len(good_dataset)} high-quality synthetic paragraph images in 'good_paragraphs'.")
    print(f"\nDataset information has been saved to {good_json_path}.")
    
    # Second step: Process images in 'good_paragraphs' to 'synthetic_paragraphs'
    synthetic_paragraph_output = os.path.join(base_dir, "synthetic_paragraphs")
    process_paragraph_images(good_paragraph_output, synthetic_paragraph_output)
    
    # Optional: Save the dataset again after processing
    synthetic_dataset = [{"images": [os.path.join(synthetic_paragraph_output, img)], "query": "what does this say?"} for img in os.listdir(synthetic_paragraph_output) if img.endswith('.png')]
    synthetic_json_path = os.path.join(base_dir, 'synthetic_paragraph_dataset.json')
    with open(synthetic_json_path, 'w') as f:
        json.dump(synthetic_dataset, f, indent=4)
    
    print(f"\nProcessed images and saved final dataset to {synthetic_json_path}.")
# Out:
# Loaded 2844 valid line entries.
#
# Generated 1000 high-quality synthetic paragraph images in 'good_paragraphs'.
#
# Dataset information has been saved to C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\good_paragraph_dataset.json.
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph1.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph10.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph100.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph1000.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph101.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph102.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph103.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph104.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph105.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph106.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph107.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph108.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph109.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph11.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph110.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph111.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph112.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph113.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph114.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph115.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph116.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph117.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph118.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph119.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph12.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph120.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph121.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph122.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph123.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph124.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph125.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph126.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph127.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph128.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph129.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph13.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph130.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph131.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph132.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph133.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph134.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph135.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph136.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph137.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph138.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph139.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph14.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph140.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph141.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph142.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph143.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph144.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph145.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph146.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph147.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph148.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph149.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph15.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph150.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph151.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph152.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph153.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph154.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph155.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph156.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph157.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph158.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph159.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph16.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph160.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph161.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph162.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph163.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph164.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph165.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph166.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph167.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph168.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph169.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph17.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph170.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph171.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph172.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph173.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph174.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph175.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph176.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph177.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph178.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph179.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph18.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph180.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph181.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph182.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph183.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph184.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph185.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph186.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph187.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph188.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph189.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph19.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph190.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph191.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph192.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph193.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph194.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph195.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph196.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph197.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph198.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph199.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph2.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph20.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph200.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph201.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagraph202.png
# Processed and saved: C:\Users\alexg\Coding Projects\Medical-Handwriting-Training-Generator\synthetic_paragraphs\goodparagra